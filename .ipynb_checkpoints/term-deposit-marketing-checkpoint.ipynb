# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('term-deposit-marketing-2020.csv')

data.age.plot.hist()

data
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 39995   53    technician   married   tertiary      no      395      no   no
# 39996   30    management    single   tertiary      no     3340      no   no
# 39997   54         admin  divorced  secondary      no      200      no   no
# 39998   34    management   married   tertiary      no     1047      no   no
# 39999   38    technician   married  secondary      no     1442     yes   no
#
#         contact  day month  duration  campaign    y
# ...

# %%
data.describe()
# Out:
#                 age        balance           day      duration      campaign
# count  40000.000000   40000.000000  40000.000000  40000.000000  40000.000000
# mean      40.544600    1274.277550     16.017225    254.824300      2.882175
# std        9.641776    2903.769716      8.278127    259.366498      3.239051
# min       19.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      54.000000      8.000000    100.000000      1.000000
# 50%       39.000000     407.000000     17.000000    175.000000      2.000000
# 75%       48.000000    1319.000000     21.000000    313.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# y            0
# dtype: int64

# %%
data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# y            object
# dtype: object

# %%
data['default'] = data['default'].map(lambda x: 0 if x=="no" else 1)
data
data.default.plot.hist()
data
# Out:
#        age           job   marital  education  default  balance housing loan  \
# 0       58    management   married   tertiary        0     2143     yes   no
# 1       44    technician    single  secondary        0       29     yes   no
# 2       33  entrepreneur   married  secondary        0        2     yes  yes
# 3       47   blue-collar   married    unknown        0     1506     yes   no
# 4       33       unknown    single    unknown        0        1      no   no
# ...    ...           ...       ...        ...      ...      ...     ...  ...
# 39995   53    technician   married   tertiary        0      395      no   no
# 39996   30    management    single   tertiary        0     3340      no   no
# 39997   54         admin  divorced  secondary        0      200      no   no
# 39998   34    management   married   tertiary        0     1047      no   no
# 39999   38    technician   married  secondary        0     1442     yes   no
#
# ...

# %%
data.drop('default', axis='columns', inplace=True)

# %%
data
# Out:
#        age           job   marital  education  balance housing loan   contact  \
# 0       58    management   married   tertiary     2143     yes   no   unknown
# 1       44    technician    single  secondary       29     yes   no   unknown
# 2       33  entrepreneur   married  secondary        2     yes  yes   unknown
# 3       47   blue-collar   married    unknown     1506     yes   no   unknown
# 4       33       unknown    single    unknown        1      no   no   unknown
# ...    ...           ...       ...        ...      ...     ...  ...       ...
# 39995   53    technician   married   tertiary      395      no   no  cellular
# 39996   30    management    single   tertiary     3340      no   no  cellular
# 39997   54         admin  divorced  secondary      200      no   no  cellular
# 39998   34    management   married   tertiary     1047      no   no  cellular
# 39999   38    technician   married  secondary     1442     yes   no  cellular
#
# ...

# %%
data.marital.value_counts()
# Out:
# married     24386
# single      10889
# divorced     4725
# Name: marital, dtype: int64

# %%
data['marital'] = data['marital'].map(lambda x: 0 if x=="single" else 1 if x=="married" else 2)
data.marital.value_counts()
# Out:
# 1    24386
# 0    10889
# 2     4725
# Name: marital, dtype: int64

# %%
data.education.value_counts()
# Out:
# secondary    20993
# tertiary     11206
# primary       6270
# unknown       1531
# Name: education, dtype: int64

# %%
data['education'] = data['education'].map(lambda x: 0 if x=="unknown" else 1 if x=="primary" else 2 if x=='secondary' else 3)
data.education.value_counts()
# Out:
# 2    20993
# 3    11206
# 1     6270
# 0     1531
# Name: education, dtype: int64

# %%
data.housing.value_counts()
# Out:
# yes    24031
# no     15969
# Name: housing, dtype: int64

# %%
data['housing'] = data['housing'].map(lambda x: 0 if x=="no" else 1)
data.housing.value_counts()
# Out:
# 1    24031
# 0    15969
# Name: housing, dtype: int64

# %%
data.loan.value_counts()
# Out:
# no     33070
# yes     6930
# Name: loan, dtype: int64

# %%
data['loan'] = data['loan'].map(lambda x: 0 if x=="no" else 1)
data.loan.value_counts()
# Out:
# 0    33070
# 1     6930
# Name: loan, dtype: int64

# %%
data.contact.value_counts()
# Out:
# cellular     24914
# unknown      12765
# telephone     2321
# Name: contact, dtype: int64

# %%
data['contact'] = data['contact'].map(lambda x: 0 if x=="unknown" else 1 if x=="cellular" else 2)
data.contact.value_counts()
# Out:
# 1    24914
# 0    12765
# 2     2321
# Name: contact, dtype: int64

# %%
data.campaign.value_counts()
# Out:
# 1     14718
# 2     11153
# 3      4970
# 4      3297
# 5      1642
# 6      1228
# 7       699
# 8       526
# 9       318
# 10      262
# 11      197
# 12      154
# 13      131
# 14       93
# 15       83
# 16       78
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 23       22
# 25       22
# 24       20
# 28       16
# 29       16
# 26       13
# 31       12
# 27       10
# 32        9
# 30        8
# 33        6
# 34        5
# 36        4
# 35        4
# 43        3
# 38        3
# 41        2
# 50        2
# 37        2
# 51        1
# 55        1
# 46        1
# 58        1
# 44        1
# 39        1
# 63        1
# Name: campaign, dtype: int64

# %%
data.job.value_counts()
# Out:
# blue-collar      9383
# management       8166
# technician       6852
# admin            4483
# services         3910
# retired          1437
# self-employed    1414
# entrepreneur     1405
# unemployed       1104
# housemaid        1087
# student           524
# unknown           235
# Name: job, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
data['job'] = LE.fit_transform(data['job'])
data
# Out:
#        age  job  marital  education  balance  housing  loan  contact  day  \
# 0       58    4        1          3     2143        1     0        0    5
# 1       44    9        0          2       29        1     0        0    5
# 2       33    2        1          2        2        1     1        0    5
# 3       47    1        1          0     1506        1     0        0    5
# 4       33   11        0          0        1        0     0        0    5
# ...    ...  ...      ...        ...      ...      ...   ...      ...  ...
# 39995   53    9        1          3      395        0     0        1    3
# 39996   30    4        0          3     3340        0     0        1    3
# 39997   54    0        2          2      200        0     0        1    3
# 39998   34    4        1          3     1047        0     0        1    3
# 39999   38    9        1          2     1442        1     0        1    3
#
#       month  duration  campaign    y
# 0       may       261         1   no
# ...

# %%
data
# Out:
#        age  job  marital  education  balance  housing  loan  contact  day  \
# 0       58    4        1          3     2143        1     0        0    5
# 1       44    9        0          2       29        1     0        0    5
# 2       33    2        1          2        2        1     1        0    5
# 3       47    1        1          0     1506        1     0        0    5
# 4       33   11        0          0        1        0     0        0    5
# ...    ...  ...      ...        ...      ...      ...   ...      ...  ...
# 39995   53    9        1          3      395        0     0        1    3
# 39996   30    4        0          3     3340        0     0        1    3
# 39997   54    0        2          2      200        0     0        1    3
# 39998   34    4        1          3     1047        0     0        1    3
# 39999   38    9        1          2     1442        1     0        1    3
#
#       month  duration  campaign    y
# 0       may       261         1   no
# ...

# %%
data.month = data.month.replace({"jan": "January",
                                                   "feb": "February",
                                                   "mar":"March",
                                                   "apr":"April",
                                                   "may":"May",
                                                   "jun":"June",
                                                   "jul":"July",
                                                   "aug":"August",
                                                   "oct":"October",
                                                   "nov":"November",
                                                   "dec":"December"})

# %%
data['month'] = pd.to_datetime(data.month, format='%B').dt.month

# %%
data['month'] = pd.to_datetime(data.month, format='%d').dt.month
data
# Out:
#        age  job  marital  education  balance  housing  loan  contact  day  \
# 0       58    4        1          3     2143        1     0        0    5
# 1       44    9        0          2       29        1     0        0    5
# 2       33    2        1          2        2        1     1        0    5
# 3       47    1        1          0     1506        1     0        0    5
# 4       33   11        0          0        1        0     0        0    5
# ...    ...  ...      ...        ...      ...      ...   ...      ...  ...
# 39995   53    9        1          3      395        0     0        1    3
# 39996   30    4        0          3     3340        0     0        1    3
# 39997   54    0        2          2      200        0     0        1    3
# 39998   34    4        1          3     1047        0     0        1    3
# 39999   38    9        1          2     1442        1     0        1    3
#
#        month  duration  campaign    y
# 0          1       261         1   no
# ...

# %%
data.y.value_counts()
data['y'] = data['y'].map(lambda x: 0 if x=="no" else 1)
data.y.value_counts()
# Out:
# 0    37104
# 1     2896
# Name: y, dtype: int64

# %%
from sklearn.model_selection import train_test_split


train_valid_X = data[data.columns.difference(['y'])]
train_valid_y = data.y
train_X , valid_X , train_y , valid_y = train_test_split( train_valid_X , train_valid_y , train_size = .8 )


print (data.shape , train_X.shape , valid_X.shape , train_y.shape , valid_y.shape)
# Out:
# (40000, 13) (32000, 12) (8000, 12) (32000,) (8000,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier

model0 = RandomForestClassifier(n_estimators=100)
model1 = SVC()
model2 = GradientBoostingClassifier()
model3 = KNeighborsClassifier(n_neighbors = 3)
model4 = GaussianNB()
model5 = LogisticRegression()

model0.fit( train_X , train_y )
model1.fit( train_X , train_y )
model2.fit( train_X , train_y )
model3.fit( train_X , train_y )
model4.fit( train_X , train_y )
model5.fit( train_X , train_y )

print ("Random Forest:", model0.score( train_X , train_y ) , model0.score( valid_X , valid_y ))
print ("SCV:", model1.score( train_X , train_y ) , model1.score( valid_X , valid_y ))
print ("Gradient Boost:", model2.score( train_X , train_y ) , model2.score( valid_X , valid_y ))
print ("K Neighbors:", model3.score( train_X , train_y ) , model3.score( valid_X , valid_y ))
print ("Gaussian:", model4.score( train_X , train_y ) , model4.score( valid_X , valid_y ))
print ("Logical Reg:", model5.score( train_X , train_y ) , model5.score( valid_X , valid_y ))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Random Forest: 0.99996875 0.93475
# SCV: 0.9995 0.927375
# Gradient Boost: 0.93884375 0.93525
# K Neighbors: 0.949625 0.92275
# Gaussian: 0.92978125 0.931625
# Logical Reg: 0.93265625 0.935125

# %%
from numpy import mean
from numpy import std
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

cv = KFold(n_splits=5, random_state=1, shuffle=True)

scores = cross_val_score(model0, train_X, train_y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Random Forest 5-fold Cross Validation Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
scores = cross_val_score(model1, train_X, train_y, scoring='accuracy', cv=cv, n_jobs=-1)
print('SCV 5-fold Cross Validation Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
scores = cross_val_score(model2, train_X, train_y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Gradient Boost 5-fold Cross Validation Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
scores = cross_val_score(model3, train_X, train_y, scoring='accuracy', cv=cv, n_jobs=-1)
print('K Neighbors 5-fold Cross Validation Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
scores = cross_val_score(model4, train_X, train_y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Gaussian 5-fold Cross Validation Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
scores = cross_val_score(model5, train_X, train_y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Logical Reg 5-fold Cross Validation Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Random Forest Accuracy: 0.932 (0.002)
# SCV Accuracy: 0.928 (0.002)
# Gradient Boost Accuracy: 0.932 (0.002)
# K Neighbors Accuracy: 0.920 (0.004)
# Gaussian Accuracy: 0.930 (0.002)
# Logical Reg Accuracy: 0.932 (0.002)
